# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
z = np.linspace(0,4,4+1)
plt.plot(z,'-o')

# %%
N = 4
x = y#np.random.rand(N)
y = x#np.random.rand(N)

plt.scatter(x,y)
plt.show()

# %%
x = np.linspace(-1.0, 1.0, 100)
y = np.linspace(-1.0, 1.0, 100)
X, Y = np.meshgrid(x,y)
F = X**2 + Y**2 - 0.4
plt.contour(X,Y,F,[0])
plt.show()

# %%
np.shape(F)
# Out:
# (100, 100)
